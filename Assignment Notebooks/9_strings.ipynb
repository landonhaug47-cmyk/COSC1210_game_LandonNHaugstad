# %% [markdown]
# ## COSC 1210
# ### Strings
#
# In this notebook, we will cover
# - string methods
# - stripping white spaces
# - searching strings for substrings
# - splitting strings into tokens
# - concatentating and joining strings

# %% [markdown]
# Strings are...
#
# - immutable
# - iterable

# %%
# A string
astring = "     Python is a versatile, readable language  .\t... \n"
print("*")
print(astring)
print("*")

print("the length is", len(astring))

for i in astring:
    if i == "e":
        print(i)
# Out:
# *
#      Python is a versatile, readable language  .	...
#
# *
# the length is 54
# e
# e
# e
# e
# e

# %%
# The 3rd index
print(astring[3])

# %%
# The -4 index
print(astring[-4])
# Out:
# .

# %%
# concatenation
print(astring + astring)
# Out:
#      Python is a versatile, readable language  .	...
#      Python is a versatile, readable language  .	...

# %%
# repetition and slicing
print(astring[0:10]*3)
# Out:
#      Pytho     Pytho     Pytho

# %% [markdown]
# ### Stripping white space
#
# Later we will learn how to process text files with Python. To do so, we can strip the white spaces so we can process the string. Those white spaces include
# - ' ' or '\s'- spaces
# - '\n' - new lines
# - '\t' - tabs

# %%
astring = "     Python is a versatile, readable language  .\t... \n"
# .strip() takes out all white spaces from the ends
print("original")
print(astring)
print("*")
print("stripped")
print(astring.strip())
print("*")
# Out:
# original
#      Python is a versatile, readable language  .	...
#
# *
# stripped
# Python is a versatile, readable language  .	...
# *

# %%
astring = "     Python is a versatile, readable language  .\t... \n"
print(astring.lstrip())
print("*")
# Out:
# Python is a versatile, readable language  .	...
#
# *

# %%
astring = "     Python is a versatile, readable language  .\t... \n"
print(astring.rstrip())
print("*")
# Out:
#      Python is a versatile, readable language  .	...
# *

# %% [markdown]
# ### Basic string methods
#
# Test these methods and determine what they do, they're pretty self-explanatory
# - .lower()
# - .upper()
# - .capitalize()
# - .title()

# %%
# test the methods here

# %%
text = "Jonah is gonna be a warden"
print(text.upper)
print(text.lower)
print(text.capitalize)
print(text.title)
# Out:
# <built-in method upper of str object at 0x0000014F07D99890>
# <built-in method lower of str object at 0x0000014F07D99890>
# <built-in method capitalize of str object at 0x0000014F07D99890>
# <built-in method title of str object at 0x0000014F07D99890>

# %% [markdown]
# ### String searching
#
# Let's say we want to find substrings in a string

# %%
# how many 'e' characters are in astring?
astring = "     Python is a versatile, readable language  .\t... \n"
astring.count('e')

# %%
# find the index of the first instance of 'e'
astring = "     Python is a versatile, readable language  .\t... \n"
astring.index('e')
# Out:
# 18

# %% [markdown]
# ### Other string methods
#
# - .startswith()
# - .endswith()

# %% [markdown]
# ### Replacing substring, splitting, joining

# %%
# Replacing a substring in a larger string
astring = "     Python is a versatile, readable language  .\t... \n"
astring.replace(" ", "-")
# Out:
# '-----Python-is-a-versatile,-readable-language--.\t...-\n'

# %%
# splitting strings
bstring = "a b c d"
print(bstring.capitalize())
print(bstring.upper())
print(bstring.split()) # the default splits on a  __________
# Out:
# A b c d
# A B C D
# ['a', 'b', 'c', 'd']

# %%
# splitting strings
cstring = "a, b, c, d"
cstring.split(', ') # the default splits on a  __________
# Out:
# ['a', 'b', 'c', 'd']

# %%
# convert a list to a string with whatever substring between elements in a list
letter_list = ['A', 'B', 'C', 'D']
','.join(letter_list)

# %%
## And if you bring in a text file that has many lines...
lines = "This is what a string that comes from a file will look\nAnd each line is seperated by newlines\nAnd you probably want to parse it\n"
print(lines)

# %%
lines.splitlines(True) # to make each line into a list

# %% [markdown]
# #### **Stop and answer this question**
#
# In the string lines above, there are newline characters. Use the .strip() method to remove the newline ending from each line

# %%
address = "Four score and seven years ago, \n all men are created equal, and the concluding line,\n government of the people, by the people, for the people, shall not perish from the earth"

word_repeated = {}
for word in address.split():
    word = word.strip(",.\n")
    if word in word_repeated:
        word_repeated[word] += 1
    else:
        word_repeated[word] = 1

print(word_repeated)
# Out:
# {'Four': 1, 'score': 1, 'and': 2, 'seven': 1, 'years': 1, 'ago': 1, 'all': 1, 'men': 1, 'are': 1, 'created': 1, 'equal': 1, 'the': 5, 'concluding': 1, 'line': 1, 'government': 1, 'of': 1, 'people': 3, 'by': 1, 'for': 1, 'shall': 1, 'not': 1, 'perish': 1, 'from': 1, 'earth': 1}
